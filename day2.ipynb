# %% [markdown]
# <a href="https://colab.research.google.com/github/vikasvickey92837-web/my-python/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#odd or even
a=int(input("enter the number"))
if a>=0:
 print("enter the even")
else:
  print("enter the odd")
# Out:
# enter the number12
# enter the even

# %%
a=int(input("enter the marks"))
if a>=90:
  print("excellent")
elif a>=80:
  print("good")
elif a>=60:
  print("average")
elif a<=50:
  print("fail")
# Out:
# enter the marks90
# excellent

# %%
#positive,negative,or zero
num=float(input("enter your number: "))
if num>0:
  print("positive number")
elif num<0:
  print("negative number")
else:
  print("zero")
# Out:
# enter your number: 5
# positive number

# %%
#largest of two number

a=float(input("enter the first number: "))
b=float(input("enter the second number: "))

if a>b:
  print("largest number is:",a)
else:
  print("largest number is:",b)
# Out:
# enter the first number: 3
# enter the second number: 2
# largest number is: 3.0

# %%
#largest of three number

a=float(input("enter the first number: "))
b=float(input("enter the second number: "))
c=float(input("enter the third number: "))

if a >= b and a>=c:
  print("largest number is:",a)
elif b >= a and b >=c:
  print("largest number is:",b)
else:
  print("largest number is:",c)
# Out:
# enter the first number: 3
# enter the second number: 4
# enter the third number: 5
# largest number is: 5.0

# %%
#leap year cheacker

year=int(input("enter a year: "))

if (year % 4 ==0 and year % 100 != 0)
 print(year,"is a leap year")
else:
  print(year,"is not a leap year")
# Out:
#   File "/tmp/ipython-input-883574841.py", line 5
#     if (year % 4 ==0 and year % 100 != 0)
#                                           ^
# SyntaxError: expected ':'

# %%
#voting eligiblity

age=int(input("enter your age"))
if age >= 18:
  print("eligible to vote")
else:
  print("not eligible to vote")
# Out:
# enter your age11
# not eligible to vote

# %%
#vowel or consonant

ch=input("enter a character: "). lower()
if ch in ['a','e','i','o','u']:
  print("vowel")
else:
  print("consonant")
# Out:
# enter a character: b
# consonant

# %%
# divisibility test (by both 3 and 5)
 a=int(input("enter a number: "))

if num %3 == 0 and num % 5 == 0:
  print("divisible by both 3 and 5")
else:
  print("not divisible by both 3 and 5")
# Out:
#   File "/tmp/ipython-input-1832308027.py", line 2
#     a=int(input("enter a number: "))
#     ^
# IndentationError: unexpected indent

# %%
# even/odd and positive/negative combined

num = int (input("enter a number: "))

if num % 2 == 0 and num > 0:
  print("even and positive")
elif num % 2 == 0 and num < 0:
  print("even and negative")
elif num % 2 == 0 and num > 0:
  print("odd and positive")
else:
  print("odd and negative")
# Out:
# enter a number: 6
# even and positive

# %%
# grade calculation

a=int(input("enter the marks"))
if a >=90:
  print("grade a")
elif a >=75:
  print("GRADE B")
elif a>=50:
  print("GRADE C")
else:
  print("FAIL")
# Out:
# enter the marks50
# GRADE C

# %%
for a in range(10,20):
 if a%2== 0:
   print("even number" )
# Out:
# even number
# even number
# even number
# even number
# even number

# %%
#FOR LOOP

for a in range(10):
  print("hello")
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
#while loop
i=1
while i<=5:
  print(1)
  i+=1
# Out:
# 1
# 1
# 1
# 1
# 1

# %%
#break

for i in range(1,6):
  if i == 3:
     break
  print(i)
# Out:
# 1
# 2

# %%
#continue

for i in range(1,6):
  if i == 3:
     continue
  print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
# pass

for i in range(1,6):
  if i ==3:
    pass
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
